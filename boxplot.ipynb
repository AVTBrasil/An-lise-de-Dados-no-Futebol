# %%
import pandas as pd

caminho = r"c:\Users\anton\Documents\tabela_clubes.csv"

df = pd.read_csv(caminho)


df.head()
# Out:
#     Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0  2017    18    America-MG        10        10       18   30:47    -17
# 1  2017     7  Athletico-PR        16         9       13   54:37     17
# 2  2017     6   Atletico-MG        17         8       13   56:43     13
# 3  2017    11         Bahia        12        12       14   39:41     -2
# 4  2017     9      Botafogo        13        12       13   38:46     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor  \
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000
#
#    Unnamed: 13  Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0          NaN          NaN         NaN          NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
colunas = ['Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16']
df2 =  df.drop(columns=colunas)
df2.head()
# Out:
#     Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0  2017    18    America-MG        10        10       18   30:47    -17
# 1  2017     7  Athletico-PR        16         9       13   54:37     17
# 2  2017     6   Atletico-MG        17         8       13   56:43     13
# 3  2017    11         Bahia        12        12       14   39:41     -2
# 4  2017     9      Botafogo        13        12       13   38:46     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000

# %% [markdown]
# Tarefas
# 1. Criar um Jupyter Notebook para iniciar a exploração dos conjuntos de
# dados
# 2. No notebook, calcular medidas de centralidade e dispersão das variáveis
# disponíveis
# 3. No notebook, criar boxplots para as variáveis disponíveis

# %%
# Calcular média e desvio padrão
media_por_time = df2.groupby('Clubes')['Media_Valor'].mean()


# Exibir as medidas de centralidade e dispersão
plt.figure(figsize=(10,6))
media_por_time.sort_values().plot(kind = 'bar', color = 'darkblue')
plt.title('Média de pontos por clube')
plt.xlabel('Média de pontos')
plt.xlabel('Clubes')
plt.grid(axis = 'y')
plt.show()

print(media_por_time)
# Out:
# Clubes
# America-MG       5.490000e+05
# Athletico-PR     7.656667e+05
# Atletico-GO      3.105000e+05
# Atletico-MG      1.178900e+06
# Avai             2.440000e+05
# Bahia            6.455000e+05
# Botafogo         5.786667e+05
# Ceara            4.156667e+05
# Chapecoense      4.760000e+05
# Corinthians      1.333200e+06
# Coritiba         6.946250e+05
# Criciuma         4.035000e+05
# Cruzeiro         1.321300e+06
# Figueirense      3.518000e+05
# Flamengo         1.382600e+06
# Fluminense       1.147100e+06
# Goias            5.370000e+05
# Gremio           1.021600e+06
# Guarani          2.430000e+05
# Internacional    1.237778e+06
# Joinville        1.210000e+05
# Nautico          6.526667e+05
# Palmeiras        1.343667e+06
# Parana           3.080000e+05
# Ponte Preta      4.162000e+05
# Portuguesa       2.360000e+05
# Prudente         1.575000e+05
# Santa Cruz       3.670000e+05
# Santo Andre      1.450000e+05
# Santos           1.247100e+06
# ...

# %%
desvio_por_time =  df2.groupby('Clubes')['Media_Valor'].std()

# Exibir as medidas de centralidade e dispersão
plt.figure(figsize=(10,6))
desvio_por_time.sort_values().plot(kind = 'bar', color = 'darkred')
plt.title('Desvio de pontos por clube')
plt.xlabel('Desvio padrão de pontos')
plt.xlabel('Clubes')
plt.grid(axis = 'y')
plt.show()
print("\nDesvios Padrão:")
print(desvio_por_time)
# Out:
# Desvios Padrão:
# Clubes
# America-MG       417651.768822
# Athletico-PR     609017.035887
# Atletico-GO       65449.726254
# Atletico-MG      447905.111479
# Avai             122735.487941
# Bahia            268013.992172
# Botafogo         198263.713271
# Ceara            145204.453559
# Chapecoense      285372.563503
# Corinthians      345028.436831
# Coritiba         605933.032014
# Criciuma          92630.988335
# Cruzeiro         409499.979650
# Figueirense      183642.859921
# Flamengo         312854.669846
# Fluminense       394824.700905
# Goias            526574.306247
# Gremio           361898.144050
# Guarani                    NaN
# Internacional    182949.294736
# Joinville                  NaN
# Nautico          547493.683373
# Palmeiras        395717.702409
# Parana                     NaN
# Ponte Preta      225882.048866
# Portuguesa        19798.989873
# Prudente         127986.327395
# Santa Cruz                 NaN
# Santo Andre                NaN
# ...

# %%
# Criar histograma para 'Vitorias'
plt.hist(df2['Vitorias'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Vitórias')
plt.ylabel('Frequência')
plt.title('Histograma de Vitórias')
plt.show()

# %%
# Criar boxplot para 'Saldo'
plt.boxplot(df2['Saldo'])
plt.xlabel('Saldo')
plt.title('Boxplot de Saldo')
plt.show()

# %%
# Exemplo de criação de boxplot para a coluna 'Vitorias'
plt.figure(figsize=(8, 6))
plt.boxplot(df2['Vitorias'])
plt.title('Boxplot de Vitórias')
plt.ylabel('Número de Vitórias')
plt.show()

# %%
vitorias_por_clube = df2.groupby('Clubes')['Vitorias'].sum()

# Ordenar os clubes pelo número de vitórias em ordem decrescente
clubes_ordenados = vitorias_por_clube.sort_values(ascending=False)

# Obter os três clubes com o maior número de vitórias
tres_melhores_times = clubes_ordenados.head(3)

print("Os três times com o maior número de vitórias:")
print(tres_melhores_times)
# Out:
# Os três times com o maior número de vitórias:
# Clubes
# Gremio         170
# Corinthians    170
# Cruzeiro       169
# Name: Vitorias, dtype: int64

# %%
tres_melhores_times = pd.DataFrame({
    'Clubes': ['Time1', 'Time2', 'Time3'],  # Substitua 'Time1', 'Time2', 'Time3' pelos nomes reais dos times
    'Vitorias': [100, 95, 90]  # Substitua 100, 95, 90 pelos números reais de vitórias dos times
})

# Criar um boxplot com os dados dos três times
plt.figure(figsize=(8, 6))
plt.boxplot(tres_melhores_times['Vitorias'])
plt.title('Boxplot do Número de Vitórias dos Três Melhores Times')
plt.ylabel('Número de Vitórias')
plt.xticks([1], ['Três Melhores Times'])
plt.grid(True)
plt.show()

# %%
dados_time = df2[df2['Clubes'] == 'Gremio']

# Criar o boxplot das vitórias ao longo do tempo
plt.figure(figsize=(10, 6))
plt.boxplot(dados_time['Vitorias'], labels=['Gremio'])
plt.title(f'Boxplot das Vitórias de Gremio ao Longo do Tempo')
plt.xlabel('Time')
plt.ylabel('Vitórias')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df2['Vitorias'], vert=False)
plt.title(f'Boxplot de Vitórias de Gremio por Ano')
plt.xlabel('Vitórias')
plt.ylabel('Ano')
plt.yticks([1], ['Gremio'])  # Nome do time no eixo y
plt.grid(True)
plt.show()

# %%
df2.head()
# Out:
#     Ano  Pos.        Clubes  Vitorias  Derrotas  Empates GolsF/S  Saldo  \
# 0  2017    18    America-MG        10        10       18   30:47    -17
# 1  2017     7  Athletico-PR        16         9       13   54:37     17
# 2  2017     6   Atletico-MG        17         8       13   56:43     13
# 3  2017    11         Bahia        12        12       14   39:41     -2
# 4  2017     9      Botafogo        13        12       13   38:46     -8
#
#    Qtd_Jogadores Idade_Media  Estrangeiros  Valor_total  Media_Valor
# 0             51        24,8             0     27350000       536000
# 1             52          24             3     37650000       724000
# 2             50        23,4             6     61350000      1230000
# 3             48        23,2             2     34900000       727000
# 4             45        23,1             4     25550000       568000

# %%
# Criar scatterplot para Valor_total vs. Media_Valor
plt.figure(figsize=(8, 6))
plt.scatter(df2['Valor_total'], df2['Media_Valor'])
plt.title('Scatterplot de Valor Total vs. Média de Valor')
plt.xlabel('Valor Total')
plt.ylabel('Média de Valor')
plt.grid(True)
plt.show()
